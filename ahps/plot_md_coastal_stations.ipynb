# %% [markdown]
# # Call Function to plot multiple stations
#      Use 'Run All Cells'

# %%
% matplotlib notebook
from functions_ahps_stage import *

# %%
gage = "BDRN4"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "BISM2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "CBBV2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "CVGV2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "EDFM2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "FDKM2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "KITO1"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "SDHN4"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "NATP1"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "PORM2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "WIBP1"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "WOLV2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "YGWO1"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">

# %%
gage = "YKTV2"
PlotStation(gage)
# Out:
# <img src="data:image/png;base64,...">
